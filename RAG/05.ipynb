# %%
from RAG import *
load_dotenv()
embed_url=os.getenv("SILI_FLOW_URL")
embed_key=os.getenv("SILI_FLOW_KEY")
#这里使用硅基流动中转平台免费的嵌入模型
embed_model=init_embeddings(
    model='BAAI/bge-m3',
    base_url=embed_url,
    api_key=embed_key,
    provider='openai',
)
text='床前明月光下一句是什么?'
#句子向量化
embeded_query=embed_model.embed_query(text=text)
print(embeded_query[:5])
print(len(embeded_query))
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[2], line 14
#      10     provider='openai',
#      11 )
#      12 text='床前明月光下一句是什么?'
#      13 #句子向量化
# ---> 14 embeded_query=embed_model.embed_query(text=text)
#      15 print(embeded_query[:5])
#      16 print(len(embeded_query))
#
# File D:\Anaconda\envs\myagent\Lib\site-packages\langchain_openai\embeddings\base.py:801, in OpenAIEmbeddings.embed_query(self, text, **kwargs)
#     791 """Call out to OpenAI's embedding endpoint for embedding query text.
#     792
#     793 Args:
#    (...)    798     Embedding for the text.
#     799 """
#     800 self._ensure_sync_client_available()
# --> 801 return self.embed_documents([text], **kwargs)[0]
#
# File D:\Anaconda\envs\myagent\Lib\site-packages\langchain_openai\embeddings\base.py:751, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     748 # Unconditionally call _get_len_safe_embeddings to handle length safety.
#     749 # This could be optimized to avoid double work when all texts are short enough.
#     750 engine = cast(str, self.deployment)
# --> 751 return self._get_len_safe_embeddings(
#     752     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     753 )
#
# File D:\Anaconda\envs\myagent\Lib\site-packages\langchain_openai\embeddings\base.py:618, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     616 # Make API call with this batch
#     617 batch_tokens = tokens[i:batch_end]
# --> 618 response = self.client.create(input=batch_tokens, **client_kwargs)
#     619 if not isinstance(response, dict):
#     620     response = response.model_dump()
#
# File D:\Anaconda\envs\myagent\Lib\site-packages\openai\resources\embeddings.py:136, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     130             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     131                 base64.b64decode(data), dtype="float32"
#     132             ).tolist()
#     134     return obj
# --> 136 return self._post(
#     137     "/embeddings",
#     138     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     139     options=make_request_options(
#     140         extra_headers=extra_headers,
#     141         extra_query=extra_query,
#     142         extra_body=extra_body,
#     143         timeout=timeout,
#     144         post_parser=parser,
#     145     ),
#     146     cast_to=CreateEmbeddingResponse,
#     147 )
#
# File D:\Anaconda\envs\myagent\Lib\site-packages\openai\_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1288     warnings.warn(
#    1289         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1290         "Please pass raw bytes via the `content` parameter instead.",
#    1291         DeprecationWarning,
#    1292         stacklevel=2,
#    1293     )
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File D:\Anaconda\envs\myagent\Lib\site-packages\openai\_base_client.py:1070, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1067             err.response.read()
#    1069         log.debug("Re-raising status error")
# -> 1070         raise self._make_status_error_from_response(err.response) from None
#    1072     break
#    1074 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'code': 30014, 'data': None, 'message': 'Token is invalid.'}

# %%
#文档向量化
csv_path='../source/test.csv'
csv_loader=CSVLoader(csv_path)
texts=[data.page_content for data in csv_loader.load()]
embed_docs=embed_model.embed_documents(texts)
for i in range(len(texts)):
    print(f"{texts[i]}:\n{embed_docs[i][:3]}",end="\n\n")
# Out:
# taskName: CRH1A-1026_20211021092200
# taskGuid: cc738ef7-61ea-4b9f-925d-2270a6202e3a
# trainNumber: CRH1A-1026
# username: 潘泽
# carriageNumber: 1
# fillTypeName: 1A-齿轮箱加注
# fillPointName: 1轴齿轮箱-换油
# planMass: 2650
# fillUnit: ml
# fillMass: 2650
# startTime: 2021/10/21 9:33:40
# endTime: 2021/10/21 10:59:47:
# [0.011670702137053013, 0.02823331579566002, -0.012928622774779797]
#
# taskName: CRH1A-1026_20211021092200
# taskGuid: cc738ef7-61ea-4b9f-925d-2270a6202e3a
# trainNumber: CRH1A-1026
# username: 潘泽
# carriageNumber: 1
# fillTypeName: 1A-齿轮箱加注
# fillPointName: 2轴齿轮箱-换油
# planMass: 2650
# fillUnit: ml
# fillMass: 2650
# startTime: 2021/10/21 9:33:40
# endTime: 2021/10/21 10:59:47:
# [0.01338114868849516, 0.02464948408305645, -0.013592429459095001]
#
# taskName: CRH1A-1026_20211021092200
# taskGuid: cc738ef7-61ea-4b9f-925d-2270a6202e3a
# trainNumber: CRH1A-1026
# username: 潘泽
# carriageNumber: 1
# fillTypeName: 1A-齿轮箱加注
# fillPointName: 3轴齿轮箱-换油
# planMass: 2650
# fillUnit: ml
# fillMass: 2650
# startTime: 2021/10/21 9:33:40
# endTime: 2021/10/21 10:59:47:
# [0.014687396585941315, 0.024149470031261444, -0.014687396585941315]
#
# taskName: CRH1A-1026_20211021092200
# taskGuid: cc738ef7-61ea-4b9f-925d-2270a6202e3a
# trainNumber: CRH1A-1026
# username: 潘泽
# carriageNumber: 1
# fillTypeName: 1A-齿轮箱加注
# fillPointName: 4轴齿轮箱-换油
# planMass: 2650
# fillUnit: ml
# fillMass: 2650
# startTime: 2021/10/21 9:33:40
# endTime: 2021/10/21 10:59:47:
# [0.01389766950160265, 0.02497347816824913, -0.015520240180194378]
#
# taskName: CRH1A-1026_20211021092200
# taskGuid: cc738ef7-61ea-4b9f-925d-2270a6202e3a
# trainNumber: CRH1A-1026
# username: 潘泽
# carriageNumber: 3
# fillTypeName: 1A-齿轮箱加注
# fillPointName: 1轴齿轮箱-换油
# planMass: 2650
# fillUnit: ml
# fillMass: 2650
# startTime: 2021/10/21 9:33:40
# endTime: 2021/10/21 10:59:47:
# [0.010503348894417286, 0.02650509588420391, -0.01311156339943409]
#
# taskName: CRH1A-1026_20211021092200
# taskGuid: cc738ef7-61ea-4b9f-925d-2270a6202e3a
# trainNumber: CRH1A-1026
# username: 潘泽
# carriageNumber: 3
# fillTypeName: 1A-齿轮箱加注
# fillPointName: 2轴齿轮箱-换油
# planMass: 2650
# fillUnit: ml
# fillMass: 2650
# startTime: 2021/10/21 9:33:40
# endTime: 2021/10/21 10:59:47:
# [0.014365281909704208, 0.026054678484797478, -0.014224446378648281]
#
# taskName: CRH1A-1026_20211021092200
# taskGuid: cc738ef7-61ea-4b9f-925d-2270a6202e3a
# trainNumber: CRH1A-1026
# username: 潘泽
# carriageNumber: 3
# fillTypeName: 1A-齿轮箱加注
# fillPointName: 3轴齿轮箱-换油
# planMass: 2650
# fillUnit: ml
# fillMass: 2650
# startTime: 2021/10/21 9:33:40
# endTime: 2021/10/21 10:59:47:
# [0.013944878242909908, 0.02591775357723236, -0.014719593338668346]
#
# taskName: CRH1A-1026_20211021092200
# taskGuid: cc738ef7-61ea-4b9f-925d-2270a6202e3a
# trainNumber: CRH1A-1026
# username: 潘泽
# carriageNumber: 3
# fillTypeName: 1A-齿轮箱加注
# fillPointName: 4轴齿轮箱-换油
# planMass: 2650
# fillUnit: ml
# fillMass: 2650
# startTime: 2021/10/21 9:33:40
# endTime: 2021/10/21 10:59:47:
# [0.012477629818022251, 0.02777506224811077, -0.015015452168881893]
#
# taskName: CRH1A-1026_20211021092200
# taskGuid: cc738ef7-61ea-4b9f-925d-2270a6202e3a
# trainNumber: CRH1A-1026
# username: 潘泽
# carriageNumber: 4
# fillTypeName: 1A-齿轮箱加注
# fillPointName: 1轴齿轮箱-换油
# planMass: 2650
# fillUnit: ml
# fillMass: 2650
# startTime: 2021/10/21 9:33:40
# endTime: 2021/10/21 10:59:47:
# [0.011878786608576775, 0.02715151198208332, -0.012020200490951538]
#
# taskName: CRH1A-1026_20211021092200
# taskGuid: cc738ef7-61ea-4b9f-925d-2270a6202e3a
# trainNumber: CRH1A-1026
# username: 潘泽
# carriageNumber: 4
# fillTypeName: 1A-齿轮箱加注
# fillPointName: 2轴齿轮箱-换油
# planMass: 2650
# fillUnit: ml
# fillMass: 2650
# startTime: 2021/10/21 9:33:40
# endTime: 2021/10/21 10:59:47:
# [0.01402974035590887, 0.024393416941165924, -0.01501675695180893]
