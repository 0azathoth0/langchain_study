# %%
from ..RAG import *
#这些各种加载器都继承自BaseLoader,实现其中的load方法，将不同的数据源统一加载为Document对象
#文档加载器，以txt加载器为例
txt_path= '../source/test.txt'
text_loader=TextLoader(file_path=txt_path,encoding='utf-8')
document=text_loader.load()
print(type(document))
# Out:
# <class 'list'>

# %%
#csv加载器
csv_path='../source/test.csv'
csv_loader=CSVLoader(csv_path)
data=csv_loader.load()
print(type(data)) # <class 'list'>
print(type(data[0])) # <class 'langchain_core.documents.base.Document'>
print(len(data)) #
print(data[0].page_content)
# Out:
# <class 'list'>
# <class 'langchain_core.documents.base.Document'>
# 10
# taskName: CRH1A-1026_20211021092200
# taskGuid: cc738ef7-61ea-4b9f-925d-2270a6202e3a
# trainNumber: CRH1A-1026
# username: 潘泽
# carriageNumber: 1
# fillTypeName: 1A-齿轮箱加注
# fillPointName: 1轴齿轮箱-换油
# planMass: 2650
# fillUnit: ml
# fillMass: 2650
# startTime: 2021/10/21 9:33:40
# endTime: 2021/10/21 10:59:47

# %%
#使用jq和jsonLoader
json_loader=JSONLoader(
    file_path='../source/test.json',
    jq_schema='.',#提取所有字段
    text_content=False,#保持原始 JSON 结构，将提取的数据转换为JSON字符串存入page_content
)
docs=json_loader.load()
rprint(docs)
# Out:
# [
#     Document(
#         metadata={'source': 'D:\\PyProject\\langchain1.2\\source\\test.json', 'seq_num': 1},
#         page_content='{"enabled": false, "reqPtTimeSeconds": 60, "ptGetInterval": 300, "ptAddress":
# "code1:Address1;code2:Address2", "ptSendNew": false, "ptVersion": "1.0.1.9", "ptGetDataDays": 3, "oldLyEnabled":
# true, "sjDeviceCodeAddress": {"DC-A2-66-40-9D-55": "ip1", "DC-A2-66-40-9D-56": "ip2", "DC-A2-66-40-9D-57": "ip3"},
# "oldLyDeviceCodeAddress": {"DC-A2-66-40-9D-55": "ip1", "DC-A2-66-40-9D-56": "ip2", "DC-A2-66-40-9D-57": "ip3"},
# "sendNodes": [{"nodeName": "PT_2_TK", "nodeDescription": "PT\\u4f20\\u8f93\\u5230\\u94c1\\u79d1\\u7cfb\\u7edf",
# "enabled": true, "deviceCode": "all", "mode": ["CC", "CS", "LD"], "address":
# "\\u4f20\\u8f93\\u5730\\u5740,\\u683c\\u5f0fhttp://ip:port/xxx", "excludeGroup": ["bianzu1", "bianzu2"]}]}'
#     )
# ]
